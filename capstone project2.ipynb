# %%
# !pip install geopy
# !pip install folium
#since those weren't installed already, so did a manual installation

from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np
import requests
import folium
import json
from pandas.io.json import json_normalize
import matplotlib
from sklearn.cluster import KMeans
#importing necessary libraries

print('Libraries imported successfully!')
# Out:
# ...
# Libraries imported successfully!

# %%
#other than these, we need beautifulsoup as well for data scrapping 
# !pip install BeautifulSoup4
from bs4 import BeautifulSoup as bst
import urllib.request
import re

print('Libraries done!')
# Out:
# ...
# Libraries done!

# %%
#this is the wikipaedia url we need to work with
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
page=urllib.request.urlopen(url)  #connecting to website

# %%
soup=bst(page,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of postal codes of Canada: M - Wikipedia</title>
# ...

# %%
#now using the regex for finding the specific parts of the page
#we need the table content which comes under class "wikitable sortable jquery-tablesorter"
regex=re.compile('^tr$')
content_list=soup.find_all(regex)

# %%
#following string gave us all the elements starting and ending with tr tag or <tr>...</tr>
content_list
# Out:
# [<tr>
#  <th>Postal Code
#  </th>
#  <th>Borough
#  </th>
#  <th>Neighbourhood
#  </th></tr>, <tr>
#  <td>M1A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>Not assigned
#  </td></tr>, <tr>
#  <td>M2A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>Not assigned
#  </td></tr>, <tr>
#  <td>M3A
#  </td>
#  <td>North York
#  </td>
#  <td>Parkwoods
#  </td></tr>, <tr>
#  <td>M4A
#  </td>
#  <td>North York
#  </td>
#  <td>Victoria Village
#  </td></tr>, <tr>
#  <td>M5A
#  </td>
#  <td>Downtown Toronto
#  </td>
#  <td>Regent Park, Harbourfront
#  </td></tr>, <tr>
#  <td>M6A
#  </td>
#  <td>North York
#  </td>
#  <td>Lawrence Manor, Lawrence Heights
#  </td></tr>, <tr>
#  <td>M7A
#  </td>
#  <td>Downtown Toronto
#  </td>
#  <td>Queen's Park, Ontario Provincial Government
#  </td></tr>, <tr>
#  <td>M8A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>Not assigned
#  </td></tr>, <tr>
#  <td>M9A
#  </td>
#  <td>Etobicoke
#  </td>
#  <td>Islington Avenue, Humber Valley Village
#  </td></tr>, <tr>
# ...

# %%
content_list[3]
# Out:
# <tr>
# <td>M3A
# </td>
# <td>North York
# </td>
# <td>Parkwoods
# </td></tr>

# %%
#checked some random elements for inspecting if search is correct

# %%
#make a list of list by using slicing of elements 
k=[]
for i in content_list:
    i=str(i).replace('\n','')
    ls=str(i).split('</td><td>')
    if len(ls)==3:
        ls[0],ls[2]=ls[0][8:],ls[2][:len(ls[2])-10]
    k.append(ls)

# %%
#converting to dataframe
df=pd.DataFrame(k[1:181],columns=['PostalCode','Borough','Neighborhood'])

# %%
df.head()
# Out:
#   PostalCode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
# PostalCode      180 non-null object
# Borough         180 non-null object
# Neighborhood    180 non-null object
# dtypes: object(3)
# memory usage: 4.3+ KB

# %%
df.replace('Not assigned',np.nan,inplace=True)                           #replace all 'Not assigned' strings with NaN values

# %%
df.dropna(inplace=True)                                                  #remove all rows with NaN values
df=df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 3 columns):
# PostalCode      103 non-null object
# Borough         103 non-null object
# Neighborhood    103 non-null object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 3 columns):
# Postal Code    103 non-null object
# Latitude       103 non-null float64
# Longitude      103 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB

# %%
df.sort_values('PostalCode',axis=0,ascending=True,inplace=True)      #sorting by postal codes

# %%
df=df.reset_index(drop=True)

# %%
df_data_1.sort_values('Postal Code',axis=0,ascending=True,inplace=True)      #sorting each values by postalcodes before merging dataframes

# %%
(df_data_1['Postal Code']==df['PostalCode'])           #proves that the data extracted is correct
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
#        ...
# 73     True
# 74     True
# 75     True
# 76     True
# 77     True
# 78     True
# 79     True
# 80     True
# 81     True
# 82     True
# 83     True
# 84     True
# 85     True
# 86     True
# 87     True
# 88     True
# 89     True
# 90     True
# 91     True
# 92     True
# 93     True
# 94     True
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# 100    True
# 101    True
# 102    True
# Length: 103, dtype: bool

# %%
new_df=pd.concat([df,df_data_1['Latitude'],df_data_1['Longitude']],axis=1)

# %%
new_df.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
l=list(new_df['Borough'].unique())
k=l[3:6]+l[7:8]
k
# Out:
# ['East Toronto', 'Central Toronto', 'Downtown Toronto', 'West Toronto']

# %%
toronto_data=new_df[new_df['Borough'].isin(k)]

# %%
toronto_data.reset_index(drop=True)          #obtaining toronto dataset by selecting from borough
# Out:
#    PostalCode           Borough  \
# 0         M4E      East Toronto
# 1         M4K      East Toronto
# 2         M4L      East Toronto
# 3         M4M      East Toronto
# 4         M4N   Central Toronto
# 5         M4P   Central Toronto
# 6         M4R   Central Toronto
# 7         M4S   Central Toronto
# 8         M4T   Central Toronto
# 9         M4V   Central Toronto
# 10        M4W  Downtown Toronto
# 11        M4X  Downtown Toronto
# 12        M4Y  Downtown Toronto
# 13        M5A  Downtown Toronto
# 14        M5B  Downtown Toronto
# 15        M5C  Downtown Toronto
# 16        M5E  Downtown Toronto
# 17        M5G  Downtown Toronto
# 18        M5H  Downtown Toronto
# 19        M5J  Downtown Toronto
# 20        M5K  Downtown Toronto
# 21        M5L  Downtown Toronto
# 22        M5N   Central Toronto
# 23        M5P   Central Toronto
# 24        M5R   Central Toronto
# 25        M5S  Downtown Toronto
# 26        M5T  Downtown Toronto
# 27        M5V  Downtown Toronto
# ...

# %%
address='Toronto, Canada'

#getting our toronto coordinates from geolocator
geolocator=Nominatim(user_agent='ny_explorer')
location=geolocator.geocode(address)
latitude=location.latitude
longitude=location.longitude
print('geographical locations of Toronto are {},{}.'.format(latitude,longitude))
# Out:
# geographical locations of Toronto are 43.6534817,-79.3839347.

# %%
toronto_data=toronto_data.reset_index(drop=True)

# %%
#creating folium maps

map_toronto=folium.Map(location=[latitude,longitude],zoom_start=11)

for lat,lng,label in zip(toronto_data['Latitude'],toronto_data['Longitude'],toronto_data['Neighborhood']):
    label=folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'DZLF0VTICX5WPVVQRVVA00UF5IZJNIMN0PZP2YCNGYLPJHBV' # your Foursquare ID
CLIENT_SECRET = 'RE53WJQRCXR4QX2NRF2IZLFPBC4VXPNVHFVM0O220QOGTPVU' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DZLF0VTICX5WPVVQRVVA00UF5IZJNIMN0PZP2YCNGYLPJHBV
# CLIENT_SECRET:RE53WJQRCXR4QX2NRF2IZLFPBC4VXPNVHFVM0O220QOGTPVU

# %%
toronto_data.loc[0,'Neighborhood']
# Out:
# 'The Beaches'

# %%
neighborhood_latitude = toronto_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = toronto_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = toronto_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of The Beaches are 43.67635739999999, -79.2930312.

# %%
radius=500
LIMIT=100
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, neighborhood_latitude, neighborhood_longitude, VERSION, radius, LIMIT)

# %%
results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f1d81b1e10aee11f20e9b3e'},
#  'response': {'venues': [{'id': '4bd461bc77b29c74a07d9282',
#     'name': 'Glen Manor Ravine',
#     'location': {'address': 'Glen Manor',
#      'crossStreet': 'Queen St.',
#      'lat': 43.67682094413784,
#      'lng': -79.29394208780985,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67682094413784,
#        'lng': -79.29394208780985}],
#      'distance': 89,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Glen Manor (Queen St.)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d159941735',
#       'name': 'Trail',
#       'pluralName': 'Trails',
#       'shortName': 'Trail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595769407',
#     'hasPerk': False},
# ...

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# type your answer here

toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West, Riverdale
# India Bazaar, The Beaches West
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West,  Lawrence Park
# Davisville
# Moore Park, Summerhill East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Rosedale
# St. James Town, Cabbagetown
# Church and Wellesley
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# Roselawn
# Forest Hill North &amp; West, Forest Hill Road Park
# The Annex, North Midtown, Yorkville
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Stn A PO Boxes
# First Canadian Place, Underground city
# Christie
# Dufferin, Dovercourt Village
# ...

# %%
print(toronto_venues.shape)
# Out:
# (1638, 7)
